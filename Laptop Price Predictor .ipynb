# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('laptop_data.csv')

# %%
s= df['ScreenResolution'][2]

# %%
s.split()[-1]
# Out:
# '1920x1080'

# %%
df['ScreenResolution']
# Out:
# 0               IPS Panel Retina Display 2560x1600
# 1                                         1440x900
# 2                                Full HD 1920x1080
# 3               IPS Panel Retina Display 2880x1800
# 4               IPS Panel Retina Display 2560x1600
#                            ...
# 1298     IPS Panel Full HD / Touchscreen 1920x1080
# 1299    IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300                                      1366x768
# 1301                                      1366x768
# 1302                                      1366x768
# Name: ScreenResolution, Length: 1303, dtype: object

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['Ram']=df['Ram'].str.replace('GB','')

# %%
df['Weight']=df['Weight'].str.replace('kg','')

# %%
df['Ram']=df['Ram'].astype('int32')
df['Weight']=df['Weight'].astype('float32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   int32
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   float32
#  11  Price             1303 non-null   float64
# dtypes: float32(1), float64(2), int32(1), int64(1), object(7)
# memory usage: 112.1+ KB

# %%
import seaborn  as sns

# %%
sns.distplot(df['Price'])
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Price', ylabel='Density'>

# %%
df['Company'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.barplot(df['Company'],df['Price'])
plt.xticks(rotation='vertical')
plt.show()
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df['TypeName'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.barplot(df['TypeName'],df['Price'] )
plt.xticks(rotation='vertical')
plt.show()
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.distplot(df['Inches'])
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Inches', ylabel='Density'>

# %%
sns.scatterplot(df['Inches'],df['Price'])
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Inches', ylabel='Price'>

# %%
df['Touchscreen']=df['ScreenResolution'].apply(lambda x:1 if 'Touchscreen' in x else 0)

# %%
df
# Out:
#       Unnamed: 0 Company            TypeName  Inches  \
# 0              0   Apple           Ultrabook    13.3
# 1              1   Apple           Ultrabook    13.3
# 2              2      HP            Notebook    15.6
# 3              3   Apple           Ultrabook    15.4
# 4              4   Apple           Ultrabook    13.3
# ...          ...     ...                 ...     ...
# 1298        1298  Lenovo  2 in 1 Convertible    14.0
# 1299        1299  Lenovo  2 in 1 Convertible    13.3
# 1300        1300  Lenovo            Notebook    14.0
# 1301        1301      HP            Notebook    15.6
# 1302        1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300                                    1366x768
# 1301                                    1366x768
# 1302                                    1366x768
#
#                                        Cpu  Ram               Memory  \
# 0                     Intel Core i5 2.3GHz    8            128GB SSD
# 1                     Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2               Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3                     Intel Core i7 2.7GHz   16            512GB SSD
# 4                     Intel Core i5 3.1GHz    8            256GB SSD
# ...                                    ...  ...                  ...
# 1298            Intel Core i7 6500U 2.5GHz    4            128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz   16            512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz    2   64GB Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz    6              1TB HDD
# 1302  Intel Celeron Dual Core N3050 1.6GHz    4            500GB HDD
#
#                                Gpu       OpSys  Weight        Price  \
# 0     Intel Iris Plus Graphics 640       macOS    1.37   71378.6832
# 1           Intel HD Graphics 6000       macOS    1.34   47895.5232
# 2            Intel HD Graphics 620       No OS    1.86   30636.0000
# 3               AMD Radeon Pro 455       macOS    1.83  135195.3360
# 4     Intel Iris Plus Graphics 650       macOS    1.37   96095.8080
# ...                            ...         ...     ...          ...
# 1298         Intel HD Graphics 520  Windows 10    1.80   33992.6400
# 1299         Intel HD Graphics 520  Windows 10    1.30   79866.7200
# 1300             Intel HD Graphics  Windows 10    1.50   12201.1200
# 1301            AMD Radeon R5 M330  Windows 10    2.19   40705.9200
# 1302             Intel HD Graphics  Windows 10    2.20   19660.3200
#
#       Touchscreen
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0
# ...           ...
# 1298            1
# 1299            1
# 1300            0
# 1301            0
# 1302            0
#
# [1303 rows x 13 columns]

# %%
sns.distplot(df['Touchscreen'])
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Touchscreen', ylabel='Density'>

# %%
df['Touchscreen'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.barplot(df['Touchscreen'],df['Price'])
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Touchscreen', ylabel='Price'>

# %%
df['Ips']=df['ScreenResolution'].apply(lambda x:1 if 'IPS Panel' in x else 0)

# %%
df['Ips'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.barplot
# Out:
# <function seaborn.categorical.barplot(*, x=None, y=None, hue=None, data=None, order=None, hue_order=None, estimator=<function mean at 0x00000199A1CC6790>, ci=95, n_boot=1000, units=None, seed=None, orient=None, color=None, palette=None, saturation=0.75, errcolor='.26', errwidth=None, capsize=None, dodge=True, ax=None, **kwargs)>

# %%
df['ScreenResolution']
# Out:
# 0               IPS Panel Retina Display 2560x1600
# 1                                         1440x900
# 2                                Full HD 1920x1080
# 3               IPS Panel Retina Display 2880x1800
# 4               IPS Panel Retina Display 2560x1600
#                            ...
# 1298     IPS Panel Full HD / Touchscreen 1920x1080
# 1299    IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300                                      1366x768
# 1301                                      1366x768
# 1302                                      1366x768
# Name: ScreenResolution, Length: 1303, dtype: object

# %%
df
# Out:
#       Unnamed: 0 Company            TypeName  Inches  \
# 0              0   Apple           Ultrabook    13.3
# 1              1   Apple           Ultrabook    13.3
# 2              2      HP            Notebook    15.6
# 3              3   Apple           Ultrabook    15.4
# 4              4   Apple           Ultrabook    13.3
# ...          ...     ...                 ...     ...
# 1298        1298  Lenovo  2 in 1 Convertible    14.0
# 1299        1299  Lenovo  2 in 1 Convertible    13.3
# 1300        1300  Lenovo            Notebook    14.0
# 1301        1301      HP            Notebook    15.6
# 1302        1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300                                    1366x768
# 1301                                    1366x768
# 1302                                    1366x768
#
#                                        Cpu  Ram               Memory  \
# 0                     Intel Core i5 2.3GHz    8            128GB SSD
# 1                     Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2               Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3                     Intel Core i7 2.7GHz   16            512GB SSD
# 4                     Intel Core i5 3.1GHz    8            256GB SSD
# ...                                    ...  ...                  ...
# 1298            Intel Core i7 6500U 2.5GHz    4            128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz   16            512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz    2   64GB Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz    6              1TB HDD
# 1302  Intel Celeron Dual Core N3050 1.6GHz    4            500GB HDD
#
#                                Gpu       OpSys  Weight        Price  \
# 0     Intel Iris Plus Graphics 640       macOS    1.37   71378.6832
# 1           Intel HD Graphics 6000       macOS    1.34   47895.5232
# 2            Intel HD Graphics 620       No OS    1.86   30636.0000
# 3               AMD Radeon Pro 455       macOS    1.83  135195.3360
# 4     Intel Iris Plus Graphics 650       macOS    1.37   96095.8080
# ...                            ...         ...     ...          ...
# 1298         Intel HD Graphics 520  Windows 10    1.80   33992.6400
# 1299         Intel HD Graphics 520  Windows 10    1.30   79866.7200
# 1300             Intel HD Graphics  Windows 10    1.50   12201.1200
# 1301            AMD Radeon R5 M330  Windows 10    2.19   40705.9200
# 1302             Intel HD Graphics  Windows 10    2.20   19660.3200
#
#       Touchscreen  Ips
# 0               0    1
# 1               0    0
# 2               0    0
# 3               0    1
# 4               0    1
# ...           ...  ...
# 1298            1    1
# 1299            1    1
# 1300            0    0
# 1301            0    0
# 1302            0    0
#
# [1303 rows x 14 columns]

# %%
df
# Out:
#       Unnamed: 0 Company            TypeName  Inches  \
# 0              0   Apple           Ultrabook    13.3
# 1              1   Apple           Ultrabook    13.3
# 2              2      HP            Notebook    15.6
# 3              3   Apple           Ultrabook    15.4
# 4              4   Apple           Ultrabook    13.3
# ...          ...     ...                 ...     ...
# 1298        1298  Lenovo  2 in 1 Convertible    14.0
# 1299        1299  Lenovo  2 in 1 Convertible    13.3
# 1300        1300  Lenovo            Notebook    14.0
# 1301        1301      HP            Notebook    15.6
# 1302        1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300                                    1366x768
# 1301                                    1366x768
# 1302                                    1366x768
#
#                                        Cpu  Ram               Memory  \
# 0                     Intel Core i5 2.3GHz    8            128GB SSD
# 1                     Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2               Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3                     Intel Core i7 2.7GHz   16            512GB SSD
# 4                     Intel Core i5 3.1GHz    8            256GB SSD
# ...                                    ...  ...                  ...
# 1298            Intel Core i7 6500U 2.5GHz    4            128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz   16            512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz    2   64GB Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz    6              1TB HDD
# 1302  Intel Celeron Dual Core N3050 1.6GHz    4            500GB HDD
#
#                                Gpu       OpSys  Weight        Price  \
# 0     Intel Iris Plus Graphics 640       macOS    1.37   71378.6832
# 1           Intel HD Graphics 6000       macOS    1.34   47895.5232
# 2            Intel HD Graphics 620       No OS    1.86   30636.0000
# 3               AMD Radeon Pro 455       macOS    1.83  135195.3360
# 4     Intel Iris Plus Graphics 650       macOS    1.37   96095.8080
# ...                            ...         ...     ...          ...
# 1298         Intel HD Graphics 520  Windows 10    1.80   33992.6400
# 1299         Intel HD Graphics 520  Windows 10    1.30   79866.7200
# 1300             Intel HD Graphics  Windows 10    1.50   12201.1200
# 1301            AMD Radeon R5 M330  Windows 10    2.19   40705.9200
# 1302             Intel HD Graphics  Windows 10    2.20   19660.3200
#
#       Touchscreen  Ips
# 0               0    1
# 1               0    0
# 2               0    0
# 3               0    1
# 4               0    1
# ...           ...  ...
# 1298            1    1
# 1299            1    1
# 1300            0    0
# 1301            0    0
# 1302            0    0
#
# [1303 rows x 14 columns]

# %%
new=df['ScreenResolution'].str.split('x',n=1,expand=True)

# %%
new
# Out:
#                                           0     1
# 0             IPS Panel Retina Display 2560  1600
# 1                                      1440   900
# 2                              Full HD 1920  1080
# 3             IPS Panel Retina Display 2880  1800
# 4             IPS Panel Retina Display 2560  1600
# ...                                     ...   ...
# 1298   IPS Panel Full HD / Touchscreen 1920  1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200  1800
# 1300                                   1366   768
# 1301                                   1366   768
# 1302                                   1366   768
#
# [1303 rows x 2 columns]

# %%
df['x_res']=new[0]
df['y_res']=new[1]

# %%
df['x_res']=df['x_res'].str.replace(',','').str.findall(r'(\d+\.?\d+)').apply(lambda x:x[0])

# %%
df['y_res']=df['y_res'].astype('int')

# %%
df['x_res']=df['x_res'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   int32
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   float32
#  11  Price             1303 non-null   float64
#  12  Touchscreen       1303 non-null   int64
#  13  Ips               1303 non-null   int64
#  14  x_res             1303 non-null   int32
#  15  y_res             1303 non-null   int32
# dtypes: float32(1), float64(2), int32(3), int64(3), object(7)
# memory usage: 142.6+ KB

# %%
df.corr()['Price']
# Out:
# Unnamed: 0     0.067984
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.191226
# Ips            0.252208
# x_res          0.556529
# y_res          0.552809
# Name: Price, dtype: float64

# %% [markdown]
# # PPI (Pixel Per Inches) this causes rise in price of laptops
# # PPI=((x_res**2)+(y_res**2))**0.5/Inches

# %%
df['ppi']=((df['x_res']**2) +(df['y_res']**2)**0.5)/df['Inches'].astype('float')

# %%
df.drop(columns=['Inches','x_res','y_res'],inplace=True)

# %%
df.head(2)
# Out:
#    Unnamed: 0 Company   TypeName                    ScreenResolution  \
# 0           0   Apple  Ultrabook  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook                            1440x900
#
#                     Cpu  Ram               Memory  \
# 0  Intel Core i5 2.3GHz    8            128GB SSD
# 1  Intel Core i5 1.8GHz    8  128GB Flash Storage
#
#                             Gpu  OpSys  Weight       Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37  71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34  47895.5232            0    0
#
#              ppi
# 0  492872.180451
# 1  155977.443609

# %%
df.corr()['Price']
# Out:
# Unnamed: 0     0.067984
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.191226
# Ips            0.252208
# ppi            0.480376
# Name: Price, dtype: float64

# %%
df.drop(columns=['ScreenResolution'],inplace=True)

# %%
df.drop(columns=['Unnamed: 0'],inplace=True)

# %%
df
# Out:
#      Company            TypeName                                   Cpu  Ram  \
# 0      Apple           Ultrabook                  Intel Core i5 2.3GHz    8
# 1      Apple           Ultrabook                  Intel Core i5 1.8GHz    8
# 2         HP            Notebook            Intel Core i5 7200U 2.5GHz    8
# 3      Apple           Ultrabook                  Intel Core i7 2.7GHz   16
# 4      Apple           Ultrabook                  Intel Core i5 3.1GHz    8
# ...      ...                 ...                                   ...  ...
# 1298  Lenovo  2 in 1 Convertible            Intel Core i7 6500U 2.5GHz    4
# 1299  Lenovo  2 in 1 Convertible            Intel Core i7 6500U 2.5GHz   16
# 1300  Lenovo            Notebook  Intel Celeron Dual Core N3050 1.6GHz    2
# 1301      HP            Notebook            Intel Core i7 6500U 2.5GHz    6
# 1302    Asus            Notebook  Intel Celeron Dual Core N3050 1.6GHz    4
#
#                    Memory                           Gpu       OpSys  Weight  \
# 0               128GB SSD  Intel Iris Plus Graphics 640       macOS    1.37
# 1     128GB Flash Storage        Intel HD Graphics 6000       macOS    1.34
# 2               256GB SSD         Intel HD Graphics 620       No OS    1.86
# 3               512GB SSD            AMD Radeon Pro 455       macOS    1.83
# 4               256GB SSD  Intel Iris Plus Graphics 650       macOS    1.37
# ...                   ...                           ...         ...     ...
# 1298            128GB SSD         Intel HD Graphics 520  Windows 10    1.80
# 1299            512GB SSD         Intel HD Graphics 520  Windows 10    1.30
# 1300   64GB Flash Storage             Intel HD Graphics  Windows 10    1.50
# 1301              1TB HDD            AMD Radeon R5 M330  Windows 10    2.19
# 1302            500GB HDD             Intel HD Graphics  Windows 10    2.20
#
#             Price  Touchscreen  Ips            ppi
# 0      71378.6832            0    1  492872.180451
# 1      47895.5232            0    0  155977.443609
# 2      30636.0000            0    0  236376.923077
# 3     135195.3360            0    1  538714.285714
# 4      96095.8080            0    1  492872.180451
# ...           ...          ...  ...            ...
# 1298   33992.6400            1    1  263391.428571
# 1299   79866.7200            1    1  770060.150376
# 1300   12201.1200            0    0  133337.428571
# 1301   40705.9200            0    0  119661.794872
# 1302   19660.3200            0    0  119661.794872
#
# [1303 rows x 12 columns]

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#              ppi
# 0  492872.180451
# 1  155977.443609
# 2  236376.923077
# 3  538714.285714
# 4  492872.180451

# %%
df['Company'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
 df.head(2)
# Out:
#   Company   TypeName                   Cpu  Ram               Memory  \
# 0   Apple  Ultrabook  Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook  Intel Core i5 1.8GHz    8  128GB Flash Storage
#
#                             Gpu  OpSys  Weight       Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37  71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34  47895.5232            0    0
#
#              ppi
# 0  492872.180451
# 1  155977.443609

# %%
df['Cpu'].str.split()[0:1]
# Out:
# 0    [Intel, Core, i5, 2.3GHz]
# Name: Cpu, dtype: object

# %%
df['Cpu Name']=df['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))

# %%
df.head(2)
# Out:
#   Company   TypeName                   Cpu  Ram               Memory  \
# 0   Apple  Ultrabook  Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook  Intel Core i5 1.8GHz    8  128GB Flash Storage
#
#                             Gpu  OpSys  Weight       Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37  71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34  47895.5232            0    0
#
#              ppi       Cpu Name
# 0  492872.180451  Intel Core i5
# 1  155977.443609  Intel Core i5

# %%
sns.barplot(x=df['Cpu brand'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Cpu brand'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-51-21271b3d07d9> in <module>
# ----> 1 sns.barplot(x=df['Cpu brand'],y=df['Price'])
#       2 plt.xticks(rotation='vertical')
#       3 plt.show()
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'Cpu brand'

# %%
def fetch_processor(text):
    if text=='Intel Core i5' or text=='Intel Core i3' or text=='Intel Core i7':
        return text
    else:
        if text.split()[0]=='Intel':
            return 'Other Intel Processor'
        else:
            return 'AMD Processor'

# %%
df['Cpu brand']=df['Cpu Name'].apply(fetch_processor)

# %%
df.sample(2)
# Out:
#      Company  TypeName                         Cpu  Ram        Memory  \
# 116       HP  Notebook  Intel Core i7 8550U 1.8GHz    8     512GB SSD
# 1294      HP  Notebook   AMD A9-Series 9410 2.9GHz    6  1.0TB Hybrid
#
#                          Gpu       OpSys  Weight       Price  Touchscreen  \
# 116   Intel UHD Graphics 620  Windows 10    1.63  57755.5200            0
# 1294      AMD Radeon R7 M440  Windows 10    2.04  29303.4672            0
#
#       Ips            ppi            Cpu Name      Cpu brand
# 116     0  263391.428571       Intel Core i7  Intel Core i7
# 1294    0  236376.923077  AMD A9-Series 9410  AMD Processor

# %%
df['Cpu brand'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df.drop(columns=['Cpu','Cpu Name'],inplace=True)

# %%
df.head(2)
# Out:
#   Company   TypeName  Ram               Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128GB SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128GB Flash Storage        Intel HD Graphics 6000
#
#    OpSys  Weight       Price  Touchscreen  Ips            ppi      Cpu brand
# 0  macOS    1.37  71378.6832            0    1  492872.180451  Intel Core i5
# 1  macOS    1.34  47895.5232            0    0  155977.443609  Intel Core i5

# %%
sns.barplot(df['Ram'],df['Price'])
plot.show()

# %%
df['Memory'].value_counts()
# Out:
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 1TB SSD                           14
# 512GB SSD +  1TB HDD              14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 16GB SSD                           3
# 512GB SSD +  2TB HDD               3
# 1TB SSD +  1TB HDD                 2
# 512GB Flash Storage                2
# 128GB SSD +  2TB HDD               2
# 256GB SSD +  500GB HDD             2
# 256GB SSD +  256GB SSD             2
# 512GB SSD +  512GB SSD             1
# 512GB SSD +  256GB SSD             1
# 512GB SSD +  1.0TB Hybrid          1
# 64GB SSD                           1
# 64GB Flash Storage +  1TB HDD      1
# 508GB Hybrid                       1
# 256GB SSD +  1.0TB Hybrid          1
# 32GB HDD                           1
# 240GB SSD                          1
# 1.0TB HDD                          1
# 1TB HDD +  1TB HDD                 1
# 128GB HDD                          1
# 8GB SSD                            1
# Name: Memory, dtype: int64

# %%
df.sample(40)
# Out:
#        Company            TypeName  Ram                     Memory  \
# 120       Acer            Notebook    6                    1TB HDD
# 138     Lenovo            Notebook    4                    1TB HDD
# 1018   Toshiba            Notebook    8                  256GB SSD
# 1194      Dell  2 in 1 Convertible    8                  256GB SSD
# 506       Asus            Notebook    8       256GB SSD +  1TB HDD
# 1116    Lenovo              Gaming   16  256GB SSD +  1.0TB Hybrid
# 1160    Lenovo           Ultrabook    8                  256GB SSD
# 176       Acer            Notebook    4                  128GB SSD
# 581       Dell            Notebook    8                  500GB HDD
# 638     Lenovo  2 in 1 Convertible    8                  256GB SSD
# 908     Lenovo            Notebook    8       128GB SSD +  1TB HDD
# 170     Huawei           Ultrabook    8                  256GB SSD
# 230       Asus            Notebook    4                    1TB HDD
# 429   Mediacom  2 in 1 Convertible    4                   32GB SSD
# 771    Samsung  2 in 1 Convertible   16                  256GB SSD
# 579       Dell            Notebook    8                  256GB SSD
# 112     Lenovo  2 in 1 Convertible    8                  256GB SSD
# 41        Dell              Gaming   16       256GB SSD +  1TB HDD
# 377       Dell            Notebook    4                  500GB HDD
# 442     Lenovo           Ultrabook    8                  256GB SSD
# 894        MSI              Gaming   16       512GB SSD +  2TB HDD
# 413       Acer  2 in 1 Convertible    8                  256GB SSD
# 510       Dell           Ultrabook    8                  128GB SSD
# 527     Lenovo            Notebook    8                    2TB HDD
# 322       Asus            Notebook    8                  256GB SSD
# 577     Lenovo              Gaming   32       256GB SSD +  1TB HDD
# 1208      Acer            Notebook    8                    1TB HDD
# 1041      Vero            Notebook    2         32GB Flash Storage
# 875       Dell           Ultrabook    8                  256GB SSD
# 770       Dell            Notebook   16                  256GB SSD
# 166       Acer            Notebook    4                    1TB HDD
# 1275      Asus           Ultrabook    8                  512GB SSD
# 872    Toshiba            Notebook    8                  256GB SSD
# 131       Dell            Notebook    4                    1TB HDD
# 62      Lenovo            Notebook    8                  256GB SSD
# 801       Asus            Notebook    8                  256GB SSD
# 576    Toshiba           Ultrabook   16                  512GB SSD
# 1272    Lenovo            Notebook    2         64GB Flash Storage
# 177        MSI              Gaming   32       512GB SSD +  1TB HDD
# 72        Dell            Notebook    8                  256GB SSD
#
#                           Gpu       OpSys  Weight        Price  Touchscreen  \
# 120     Intel HD Graphics 620  Windows 10    2.10   25521.1200            1
# 138      Nvidia GeForce 920MX       No OS    2.20   26586.7200            0
# 1018    Intel HD Graphics 520  Windows 10    1.47   79387.2000            0
# 1194    Intel HD Graphics 620  Windows 10    1.60   63882.7200            1
# 506     Intel HD Graphics 620  Windows 10    2.00   65214.7200            0
# 1116  Nvidia GeForce GTX 980M  Windows 10    4.60  146519.4672            0
# 1160    Intel HD Graphics 520   Windows 7    1.70   79866.7200            0
# 176     Intel HD Graphics 520  Windows 10    2.10   23922.7200            0
# 581     Intel HD Graphics 620  Windows 10    1.90   53733.9456            0
# 638     Intel HD Graphics 620  Windows 10    1.37   93635.3376            1
# 908   Nvidia GeForce GTX 960M  Windows 10    2.60   42037.9200            0
# 170     Intel HD Graphics 620  Windows 10    1.05   71874.7200            0
# 230     Intel HD Graphics 620  Windows 10    2.37   21258.1872            0
# 429     Intel HD Graphics 500  Windows 10    1.16   15930.7200            1
# 771            AMD Radeon 540  Windows 10    1.71   95850.7200            1
# 579        AMD Radeon R5 M430       Linux    2.20   39907.2528            0
# 112     Intel HD Graphics 620  Windows 10    1.37   74538.7200            1
# 41    Nvidia GeForce GTX 1060  Windows 10    2.65   79866.7200            0
# 377     Intel HD Graphics 400  Windows 10    1.80   16463.5200            0
# 442     Intel HD Graphics 620  Windows 10    1.36   76137.1200            0
# 894   Nvidia GeForce GTX 1060  Windows 10    2.43  141138.7200            0
# 413     Intel HD Graphics 520  Windows 10    1.60   42038.4528            1
# 510     Intel HD Graphics 620  Windows 10    1.29   47898.7200            1
# 527     Nvidia GeForce 920MX        No OS    2.20   24455.5200            0
# 322     Intel HD Graphics 620  Windows 10    2.00   58288.3200            0
# 577   Nvidia GeForce GTX 1070  Windows 10    4.60  141884.6400            0
# 1208     Nvidia GeForce 940MX  Windows 10    3.30   33513.1200            0
# 1041    Intel HD Graphics 400  Windows 10    1.45   11231.4240            0
# 875     Intel HD Graphics 620  Windows 10    1.60   90043.2000            0
# 770        AMD Radeon R7 M445  Windows 10    2.30   62938.0656            0
# 166     Intel HD Graphics 505  Windows 10    2.10   19367.8128            0
# 1275    Intel HD Graphics 515  Windows 10    1.20   38841.1200            0
# 872     Intel HD Graphics 620  Windows 10    2.00   73952.6400            0
# 131        AMD Radeon R5 M430  Windows 10    2.20   23922.7200            0
# 62      Intel HD Graphics 620       No OS    1.70   31914.7200            0
# 801     Intel HD Graphics 620  Windows 10    2.37   58554.7200            0
# 576     Intel HD Graphics 620  Windows 10    1.24   99367.2000            1
# 1272        Intel HD Graphics  Windows 10    1.50   12201.1200            0
# 177        Nvidia GTX 980 SLI  Windows 10    4.40  149130.7200            0
# 72             AMD Radeon 530  Windows 10    2.20   46353.6000            0
#
#       Ips            ppi              Cpu brand
# 120     1  236376.923077          Intel Core i3
# 138     0  236376.923077          Intel Core i5
# 1018    1  263391.428571          Intel Core i5
# 1194    1  277254.135338          Intel Core i5
# 506     0  236376.923077          Intel Core i7
# 1116    1  213149.132948          Intel Core i7
# 1160    0  263391.428571          Intel Core i7
# 176     0  119661.794872          Intel Core i3
# 581     0  119661.794872          Intel Core i5
# 638     1  277254.135338          Intel Core i7
# 908     1  236376.923077          Intel Core i5
# 170     1  359003.076923          Intel Core i5
# 230     0  119661.794872          Intel Core i3
# 429     1  317886.206897  Other Intel Processor
# 771     0  245832.000000          Intel Core i7
# 579     0  236376.923077          Intel Core i7
# 112     1  277254.135338          Intel Core i5
# 41      1  236376.923077          Intel Core i7
# 377     0  119661.794872  Other Intel Processor
# 442     1  294998.400000          Intel Core i5
# 894     1  852471.676301          Intel Core i7
# 413     1  277254.135338          Intel Core i7
# 510     1  277254.135338          Intel Core i5
# 527     0  119661.794872          Intel Core i3
# 322     0  263391.428571          Intel Core i7
# 577     1  213149.132948          Intel Core i7
# 1208    0  148028.901734          Intel Core i3
# 1041    0  133337.428571  Other Intel Processor
# 875     0  294998.400000          Intel Core i7
# 770     0  236376.923077          Intel Core i7
# 166     0  119661.794872  Other Intel Processor
# 1275    1  277254.135338  Other Intel Processor
# 872     1  236376.923077          Intel Core i7
# 131     0  236376.923077          Intel Core i3
# 62      1  263391.428571          Intel Core i3
# 801     0  236376.923077          Intel Core i5
# 576     0  263391.428571          Intel Core i7
# 1272    0  133337.428571  Other Intel Processor
# 177     0  200406.521739          Intel Core i7
# 72      0  236376.923077          Intel Core i7

# %%
df['Memory']=df['Memory'].astype(str).replace('\.0','',regex=True)
df['Memory']=df['Memory'].str.replace('GB','')
df['Memory']=df['Memory'].str.replace('TB','000')
new=df['Memory'].str.split("+",n=1,expand=True)
df['first']=new[0]
df['first']=df['first'].str.strip()

df['second']=new[1]

df['Layer1HDD']=df['first'].apply(lambda x:1 if 'HDD' in x else 0)
df['Layer1SSD']=df['first'].apply(lambda x:1 if 'SSD' in x else 0)
df['Layer1Hybrid']=df['first'].apply(lambda x:1 if 'Hybrid' in x else 0)
df['Layer1Flash_Storage']=df['first'].apply(lambda x:1 if 'Flash Storage' in x else 0)

df['first']=df['first'].str.replace(r'\D','')
df['second'].fillna('0',inplace=True)

   
df['Layer2HDD']=df['second'].apply(lambda x:1 if 'HDD' in x else 0)
df['Layer2SSD']=df['second'].apply(lambda x:1 if 'SSD' in x else 0)
df['Layer2Hybrid']=df['second'].apply(lambda x:1 if 'Hybrid' in x else 0)
df['Layer2Flash_Storage']=df['second'].apply(lambda x:1 if 'Flash Storage' in x else 0)
   
df['second']=df['second'].str.replace(r'\D','')
   

df['first']=df['first'].astype(int)
df['second']=df['second'].astype(int)
# Out:
# <ipython-input-80-982b2768857b>:15: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['first']=df['first'].str.replace(r'\D','')
# <ipython-input-80-982b2768857b>:24: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['second']=df['second'].str.replace(r'\D','')

# %%
df['HDD']=(df['first']*df['Layer1HDD'] +df['second']*df['Layer2HDD'])
df['SSD']=(df['first']*df['Layer1SSD']+df['second']*df["Layer2SSD"])
df['Hybrid']=(df['first']*df['Layer1Hybrid']+df['second']*df['Layer2Hybrid'])
df['Flash_storage']=(df['first']*df['Layer1Flash_Storage']+df['second']*df['Layer2Flash_Storage'])

# %%
df.drop(columns=['Layer1HDD','Layer1SDD','Layer1Hybrid','Layer1Flash_Storage'],inplace=True)

# %%
df
# Out:
#      Company            TypeName  Ram             Memory  \
# 0      Apple           Ultrabook    8            128 SSD
# 1      Apple           Ultrabook    8  128 Flash Storage
# 2         HP            Notebook    8            256 SSD
# 3      Apple           Ultrabook   16            512 SSD
# 4      Apple           Ultrabook    8            256 SSD
# ...      ...                 ...  ...                ...
# 1298  Lenovo  2 in 1 Convertible    4            128 SSD
# 1299  Lenovo  2 in 1 Convertible   16            512 SSD
# 1300  Lenovo            Notebook    2   64 Flash Storage
# 1301      HP            Notebook    6           1000 HDD
# 1302    Asus            Notebook    4            500 HDD
#
#                                Gpu       OpSys  Weight        Price  \
# 0     Intel Iris Plus Graphics 640       macOS    1.37   71378.6832
# 1           Intel HD Graphics 6000       macOS    1.34   47895.5232
# 2            Intel HD Graphics 620       No OS    1.86   30636.0000
# 3               AMD Radeon Pro 455       macOS    1.83  135195.3360
# 4     Intel Iris Plus Graphics 650       macOS    1.37   96095.8080
# ...                            ...         ...     ...          ...
# 1298         Intel HD Graphics 520  Windows 10    1.80   33992.6400
# 1299         Intel HD Graphics 520  Windows 10    1.30   79866.7200
# 1300             Intel HD Graphics  Windows 10    1.50   12201.1200
# 1301            AMD Radeon R5 M330  Windows 10    2.19   40705.9200
# 1302             Intel HD Graphics  Windows 10    2.20   19660.3200
#
#       Touchscreen  Ips            ppi              Cpu brand   HDD  SSD  \
# 0               0    1  492872.180451          Intel Core i5     0  128
# 1               0    0  155977.443609          Intel Core i5     0    0
# 2               0    0  236376.923077          Intel Core i5     0  256
# 3               0    1  538714.285714          Intel Core i7     0  512
# 4               0    1  492872.180451          Intel Core i5     0  256
# ...           ...  ...            ...                    ...   ...  ...
# 1298            1    1  263391.428571          Intel Core i7     0  128
# 1299            1    1  770060.150376          Intel Core i7     0  512
# 1300            0    0  133337.428571  Other Intel Processor     0    0
# 1301            0    0  119661.794872          Intel Core i7  1000    0
# 1302            0    0  119661.794872  Other Intel Processor   500    0
#
#       Hybrid  Flash_storage
# 0          0              0
# 1          0            128
# 2          0              0
# 3          0              0
# 4          0              0
# ...      ...            ...
# 1298       0              0
# 1299       0              0
# 1300       0             64
# 1301       0              0
# 1302       0              0
#
# [1303 rows x 16 columns]

# %%
df.corr()['Price']
# Out:
# Ram              0.743007
# Weight           0.210370
# Price            1.000000
# Touchscreen      0.191226
# Ips              0.252208
# ppi              0.480376
# HDD             -0.096441
# SSD              0.670799
# Hybrid           0.007989
# Flash_storage   -0.040511
# Name: Price, dtype: float64

# %%
df.rename(columns={'h1':'hybrid','Flash_storage':'f1'},inplace=True)

# %%
df.drop(columns=['hybrid','f1'],inplace=True)

# %%
df['Gpu'].value_counts().pt(kind='bar')
plt.xticks(rotation='vertical')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-129-6cedec6e9e06> in <module>
# ----> 1 df['Gpu'].value_counts().pt(kind='bar')
#       2 plt.xticks(rotation='vertical')
#       3 plt.show()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'pt'

# %%
df.corr()['Price']
# Out:
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.191226
# Ips            0.252208
# ppi            0.480376
# HDD           -0.096441
# SSD            0.670799
# Name: Price, dtype: float64

# %%
df['Gpu'].value_counts()
# Out:
# Intel HD Graphics 620       281
# Intel HD Graphics 520       185
# Intel UHD Graphics 620       68
# Nvidia GeForce GTX 1050      66
# Nvidia GeForce GTX 1060      48
#                            ...
# Nvidia GeForce GTX1060        1
# Intel Iris Pro Graphics       1
# Nvidia GTX 980 SLI            1
# AMD Radeon R5 520             1
# Nvidia GeForce GTX 930MX      1
# Name: Gpu, Length: 110, dtype: int64

# %%
df['Gpu brand']=df['Gpu'].apply(lambda x:x.split()[0])

# %%
sns.barplot(df['Gpu brand'],df['Price'])
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Gpu brand', ylabel='Price'>

# %%
df.head()
# Out:
#   Company   TypeName  Ram             Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128 SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128 Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256 SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512 SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256 SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight        Price  Touchscreen  Ips            ppi      Cpu brand  \
# 0  macOS    1.37   71378.6832            0    1  492872.180451  Intel Core i5
# 1  macOS    1.34   47895.5232            0    0  155977.443609  Intel Core i5
# 2  No OS    1.86   30636.0000            0    0  236376.923077  Intel Core i5
# 3  macOS    1.83  135195.3360            0    1  538714.285714  Intel Core i7
# 4  macOS    1.37   96095.8080            0    1  492872.180451  Intel Core i5
#
#    HDD  SSD Gpu brand
# 0    0  128     Intel
# 1    0    0     Intel
# 2    0  256     Intel
# 3    0  512       AMD
# 4    0  256     Intel

# %%
df.corr()['Price']
# Out:
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.191226
# Ips            0.252208
# ppi            0.480376
# HDD           -0.096441
# SSD            0.670799
# Name: Price, dtype: float64

# %%
df=df[df['Gpu brand'] != 'ARM']

# %%
df['Gpu brand'].value_counts()
# Out:
# Intel     722
# Nvidia    400
# AMD       180
# Name: Gpu brand, dtype: int64

# %%
sns.barplot(df['Gpu brand'],df['Price'])
plt.show()
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df.drop(columns=['Gpu'],inplace=True)
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df.head(2)
# Out:
#   Company   TypeName  Ram             Memory  OpSys  Weight       Price  \
# 0   Apple  Ultrabook    8            128 SSD  macOS    1.37  71378.6832
# 1   Apple  Ultrabook    8  128 Flash Storage  macOS    1.34  47895.5232
#
#    Touchscreen  Ips            ppi      Cpu brand  HDD  SSD Gpu brand
# 0            0    1  492872.180451  Intel Core i5    0  128     Intel
# 1            0    0  155977.443609  Intel Core i5    0    0     Intel

# %%
df['OpSys'].value_counts()
# Out:
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         26
# macOS             13
# Windows 10 S       8
# Mac OS X           8
# Android            2
# Name: OpSys, dtype: int64

# %%
sns.barplot(df['OpSys'],df['Price'])
plt.xticks(rotation='vertical')
plt.show()
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df[df['OpSys']=='Windows 7' ]
# Out:
#       Company            TypeName  Ram       Memory      OpSys  Weight  \
# 525    Lenovo            Notebook    8      256 SSD  Windows 7    2.02
# 621    Lenovo            Notebook    8      256 SSD  Windows 7    1.65
# 624        HP            Notebook    4      500 HDD  Windows 7    1.88
# 707    Lenovo         Workstation   16      512 SSD  Windows 7    2.18
# 749        HP         Workstation   16      256 SSD  Windows 7    3.00
# 757        HP         Workstation    8      256 SSD  Windows 7    2.59
# 776    Lenovo            Notebook   16      512 SSD  Windows 7    2.50
# 844        HP           Ultrabook    8      512 SSD  Windows 7    1.54
# 952   Toshiba            Notebook    8      256 SSD  Windows 7    1.20
# 976    Lenovo            Notebook    4   508 Hybrid  Windows 7    1.70
# 981   Toshiba            Notebook    4      128 SSD  Windows 7    1.20
# 1007       HP           Ultrabook    8      256 SSD  Windows 7    1.43
# 1017   Lenovo            Notebook   16      512 SSD  Windows 7    2.40
# 1033       HP            Notebook    8      256 SSD  Windows 7    1.95
# 1038     Dell            Notebook    8      256 SSD  Windows 7    2.09
# 1046       HP            Notebook    8      256 SSD  Windows 7    1.43
# 1050   Lenovo            Notebook   16      256 SSD  Windows 7    1.10
# 1072       HP           Ultrabook    8      256 SSD  Windows 7    1.26
# 1079       HP            Notebook    4      500 HDD  Windows 7    2.31
# 1085       HP            Notebook    4      500 HDD  Windows 7    1.54
# 1086       HP         Workstation    8      256 SSD  Windows 7    1.90
# 1087   Lenovo            Notebook    8      180 SSD  Windows 7    1.70
# 1094       HP             Netbook    4      128 SSD  Windows 7    2.40
# 1100     Dell           Ultrabook    4      500 HDD  Windows 7    1.50
# 1101     Dell           Ultrabook    4      128 SSD  Windows 7    1.50
# 1103       HP         Workstation    8     1000 HDD  Windows 7    3.00
# 1105     Dell           Ultrabook    8      256 SSD  Windows 7    1.50
# 1111     Dell            Notebook    4      500 HDD  Windows 7    2.24
# 1122       HP            Notebook    8      256 SSD  Windows 7    1.43
# 1127       HP           Ultrabook    8      256 SSD  Windows 7    1.26
# 1131   Lenovo  2 in 1 Convertible    8      512 SSD  Windows 7    1.80
# 1136       HP         Workstation    8      256 SSD  Windows 7    3.00
# 1139       HP           Ultrabook    8      256 SSD  Windows 7    1.88
# 1143       HP         Workstation    8      256 SSD  Windows 7    2.59
# 1145       HP         Workstation    8      256 SSD  Windows 7    2.00
# 1146       HP           Ultrabook    8      256 SSD  Windows 7    1.26
# 1148       HP            Notebook    8      256 SSD  Windows 7    1.88
# 1157   Lenovo           Ultrabook   12      512 SSD  Windows 7    1.40
# 1160   Lenovo           Ultrabook    8      256 SSD  Windows 7    1.70
# 1176   Lenovo            Notebook    4  1000 Hybrid  Windows 7    2.32
# 1223     Dell           Ultrabook    8      256 SSD  Windows 7    1.26
# 1236       HP           Ultrabook    8      256 SSD  Windows 7    1.54
# 1237     Dell            Notebook    4      500 HDD  Windows 7    2.24
# 1244       HP            Notebook    4      256 SSD  Windows 7    1.54
# 1258   Lenovo            Notebook    8  1000 Hybrid  Windows 7    2.32
#
#             Price  Touchscreen  Ips            ppi              Cpu brand  \
# 525    71395.2000            0    0  263391.428571          Intel Core i5
# 621    78055.2000            0    0  263391.428571          Intel Core i5
# 624    49656.9600            0    0  119661.794872          Intel Core i5
# 707    98834.4000            0    0  236376.923077          Intel Core i7
# 749   233845.9200            0    1  213149.132948  Other Intel Processor
# 757    83170.0800            0    0  236376.923077          Intel Core i7
# 776   126273.6000            0    0  945369.230769          Intel Core i7
# 844    99633.6000            0    0  263391.428571          Intel Core i7
# 952    77788.8000            0    0  277254.135338          Intel Core i5
# 976    53386.5600            0    0  133337.428571          Intel Core i5
# 981    63669.6000            0    0  277254.135338          Intel Core i5
# 1007   77202.7200            0    0  263391.428571          Intel Core i7
# 1017  158135.0400            0    1  852471.676301          Intel Core i7
# 1033   63669.6000            0    0  263391.428571          Intel Core i5
# 1038   56633.9760            0    0  236376.923077          Intel Core i5
# 1046   78268.3200            0    0  263391.428571          Intel Core i5
# 1050  139593.6000            0    1  468217.142857          Intel Core i7
# 1072   63882.7200            0    0  294998.400000          Intel Core i5
# 1079   50083.2000            0    0  236376.923077          Intel Core i5
# 1085   54931.1472            0    0  263391.428571          Intel Core i5
# 1086   79653.6000            0    0  236376.923077          Intel Core i7
# 1087   63882.7200            0    0  263391.428571          Intel Core i5
# 1094   85194.7200            0    0  149337.920000          Intel Core i5
# 1100   60480.7920            0    0  149337.920000          Intel Core i3
# 1101   62176.1616            0    0  149337.920000          Intel Core i3
# 1103  154458.7200            0    1  213149.132948          Intel Core i7
# 1105   75289.9680            0    0  149337.920000          Intel Core i5
# 1111   40980.3120            0    0  119661.794872          Intel Core i5
# 1122   80612.6400            0    0  263391.428571          Intel Core i5
# 1127  100965.6000            0    0  149337.920000          Intel Core i5
# 1131  109244.2464            1    1  263391.428571          Intel Core i7
# 1136  210424.0320            0    1  213149.132948          Intel Core i7
# 1139  115709.2416            0    0  236376.923077          Intel Core i7
# 1143  118761.1200            0    1  236376.923077          Intel Core i7
# 1145  101178.7200            0    0  236376.923077          Intel Core i7
# 1146  122381.4960            0    0  294998.400000          Intel Core i7
# 1148   84129.1200            0    0  236376.923077          Intel Core i5
# 1157  122490.7200            0    0  263391.428571          Intel Core i7
# 1160   79866.7200            0    0  263391.428571          Intel Core i7
# 1176   43956.0000            0    0  236376.923077          Intel Core i7
# 1223   91288.3536            1    0  294998.400000          Intel Core i5
# 1236  117119.5632            0    0  468217.142857          Intel Core i7
# 1237   39267.3600            0    0  119661.794872          Intel Core i5
# 1244   58607.4672            0    0  263391.428571          Intel Core i5
# 1258   47685.6000            0    0  236376.923077          Intel Core i7
#
#        HDD  SSD Gpu brand
# 525      0  256     Intel
# 621      0  256     Intel
# 624    500    0     Intel
# 707      0  512    Nvidia
# 749      0  256    Nvidia
# 757      0  256    Nvidia
# 776      0  512    Nvidia
# 844      0  512     Intel
# 952      0  256     Intel
# 976      0    0     Intel
# 981      0  128     Intel
# 1007     0  256     Intel
# 1017     0  512    Nvidia
# 1033     0  256     Intel
# 1038     0  256     Intel
# 1046     0  256     Intel
# 1050     0  256     Intel
# 1072     0  256     Intel
# 1079   500    0     Intel
# 1085   500    0     Intel
# 1086     0  256       AMD
# 1087     0  180     Intel
# 1094     0  128     Intel
# 1100   500    0     Intel
# 1101     0  128     Intel
# 1103  1000    0       AMD
# 1105     0  256     Intel
# 1111   500    0       AMD
# 1122     0  256     Intel
# 1127     0  256     Intel
# 1131     0  512    Nvidia
# 1136     0  256    Nvidia
# 1139     0  256     Intel
# 1143     0  256    Nvidia
# 1145     0  256    Nvidia
# 1146     0  256     Intel
# 1148     0  256     Intel
# 1157     0  512     Intel
# 1160     0  256     Intel
# 1176     0    0     Intel
# 1223     0  256     Intel
# 1236     0  256     Intel
# 1237   500    0     Intel
# 1244     0  256     Intel
# 1258     0    0       AMD

# %%
df.head()
# Out:
#   Company   TypeName  Ram             Memory  OpSys  Weight        Price  \
# 0   Apple  Ultrabook    8            128 SSD  macOS    1.37   71378.6832
# 1   Apple  Ultrabook    8  128 Flash Storage  macOS    1.34   47895.5232
# 2      HP   Notebook    8            256 SSD  No OS    1.86   30636.0000
# 3   Apple  Ultrabook   16            512 SSD  macOS    1.83  135195.3360
# 4   Apple  Ultrabook    8            256 SSD  macOS    1.37   96095.8080
#
#    Touchscreen  Ips            ppi      Cpu brand  HDD  SSD Gpu brand
# 0            0    1  492872.180451  Intel Core i5    0  128     Intel
# 1            0    0  155977.443609  Intel Core i5    0    0     Intel
# 2            0    0  236376.923077  Intel Core i5    0  256     Intel
# 3            0    1  538714.285714  Intel Core i7    0  512       AMD
# 4            0    1  492872.180451  Intel Core i5    0  256     Intel

# %%
def cat_os(data):
    if data =='Windows 7' or data == 'Windows 10' or data == 'Windows 10 s':
        return 'Windows'
    elif data == 'macOS' or data=='Mac OS X':
        return 'Mac'
    else:
        return 'Others/ No OS / Linux'

# %%
df['OS']=df['OpSys'].apply(cat_os)
# Out:
# <ipython-input-166-a05a9461e58a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['OS']=df['OpSys'].apply(cat_os)

# %%
df.head(2)
# Out:
#   Company   TypeName  Ram             Memory  OpSys  Weight       Price  \
# 0   Apple  Ultrabook    8            128 SSD  macOS    1.37  71378.6832
# 1   Apple  Ultrabook    8  128 Flash Storage  macOS    1.34  47895.5232
#
#    Touchscreen  Ips            ppi      Cpu brand  HDD  SSD Gpu brand   OS
# 0            0    1  492872.180451  Intel Core i5    0  128     Intel  Mac
# 1            0    0  155977.443609  Intel Core i5    0    0     Intel  Mac

# %%
sns.barplot(df['OS'],df['Price'])
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='OS', ylabel='Price'>

# %%
df.drop(columns='Memory',inplace=True)
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df.head()
# Out:
#   Company   TypeName  Ram  Weight        Price  Touchscreen  Ips  \
# 0   Apple  Ultrabook    8    1.37   71378.6832            0    1
# 1   Apple  Ultrabook    8    1.34   47895.5232            0    0
# 2      HP   Notebook    8    1.86   30636.0000            0    0
# 3   Apple  Ultrabook   16    1.83  135195.3360            0    1
# 4   Apple  Ultrabook    8    1.37   96095.8080            0    1
#
#              ppi      Cpu brand  HDD  SSD Gpu brand                     OS
# 0  492872.180451  Intel Core i5    0  128     Intel                    Mac
# 1  155977.443609  Intel Core i5    0    0     Intel                    Mac
# 2  236376.923077  Intel Core i5    0  256     Intel  Others/ No OS / Linux
# 3  538714.285714  Intel Core i7    0  512       AMD                    Mac
# 4  492872.180451  Intel Core i5    0  256     Intel                    Mac

# %%
sns.distplot(df['Weight'])
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Weight', ylabel='Density'>

# %%
sns.scatterplot(df['Weight'],df['Price'])
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Weight', ylabel='Price'>

# %%
sns.distplot(np.log(df['Price']))
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Price', ylabel='Density'>

# %%
np.log(df['Price'])
# Out:
# 0       11.175755
# 1       10.776777
# 2       10.329931
# 3       11.814476
# 4       11.473101
#           ...
# 1298    10.433899
# 1299    11.288115
# 1300     9.409283
# 1301    10.614129
# 1302     9.886358
# Name: Price, Length: 1302, dtype: float64

# %%
X=df.drop(columns=['Price'])
y=np.log(df['Price'])

# %%
df.corr()['HDD']
# Out:
# Ram            0.095808
# Weight         0.514147
# Price         -0.096891
# Touchscreen   -0.208766
# Ips           -0.093588
# ppi           -0.185949
# HDD            1.000000
# SSD           -0.400750
# Name: HDD, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.15,random_state=2)

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1106 entries, 183 to 1193
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Company      1106 non-null   object
#  1   TypeName     1106 non-null   object
#  2   Ram          1106 non-null   int32
#  3   Weight       1106 non-null   float32
#  4   Touchscreen  1106 non-null   int64
#  5   Ips          1106 non-null   int64
#  6   ppi          1106 non-null   float64
#  7   Cpu brand    1106 non-null   object
#  8   HDD          1106 non-null   int64
#  9   SSD          1106 non-null   int64
#  10  Gpu brand    1106 non-null   object
#  11  OS           1106 non-null   object
# dtypes: float32(1), float64(1), int32(1), int64(4), object(5)
# memory usage: 103.7+ KB

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first',),[0,1,7,10,11])
],remainder='passthrough')
step2= DecisionTreeRegressor(max_depth=8)

pipe=Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)
print('R2 Score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 Score 0.8282438159625976
# MAE 0.19194261411844804

# %%
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first',),[0,1,7,10,11])
],remainder='passthrough')
step2= RandomForestRegressor(n_estimators=100,
                            random_state=3,
                            max_samples=0.5,
                            max_features=0.75,
                            max_depth=15)

pipe=Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)
print('R2 Score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 Score 0.8874386350391024
# MAE 0.15912441716277018

# %%
##EXPORTING THE MODEL

# %%
import pickle

pickle.dump(df,open('df.pkl','wb'))
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
 df.head(2)
# Out:
#   Company   TypeName  Ram  Weight       Price  Touchscreen  Ips  \
# 0   Apple  Ultrabook    8    1.37  71378.6832            0    1
# 1   Apple  Ultrabook    8    1.34  47895.5232            0    0
#
#              ppi      Cpu brand  HDD  SSD Gpu brand   OS
# 0  492872.180451  Intel Core i5    0  128     Intel  Mac
# 1  155977.443609  Intel Core i5    0    0     Intel  Mac

# %%
X
# Out:
#      Company            TypeName  Ram  Weight  Touchscreen  Ips  \
# 0      Apple           Ultrabook    8    1.37            0    1
# 1      Apple           Ultrabook    8    1.34            0    0
# 2         HP            Notebook    8    1.86            0    0
# 3      Apple           Ultrabook   16    1.83            0    1
# 4      Apple           Ultrabook    8    1.37            0    1
# ...      ...                 ...  ...     ...          ...  ...
# 1298  Lenovo  2 in 1 Convertible    4    1.80            1    1
# 1299  Lenovo  2 in 1 Convertible   16    1.30            1    1
# 1300  Lenovo            Notebook    2    1.50            0    0
# 1301      HP            Notebook    6    2.19            0    0
# 1302    Asus            Notebook    4    2.20            0    0
#
#                 ppi              Cpu brand   HDD  SSD Gpu brand  \
# 0     492872.180451          Intel Core i5     0  128     Intel
# 1     155977.443609          Intel Core i5     0    0     Intel
# 2     236376.923077          Intel Core i5     0  256     Intel
# 3     538714.285714          Intel Core i7     0  512       AMD
# 4     492872.180451          Intel Core i5     0  256     Intel
# ...             ...                    ...   ...  ...       ...
# 1298  263391.428571          Intel Core i7     0  128     Intel
# 1299  770060.150376          Intel Core i7     0  512     Intel
# 1300  133337.428571  Other Intel Processor     0    0     Intel
# 1301  119661.794872          Intel Core i7  1000    0       AMD
# 1302  119661.794872  Other Intel Processor   500    0     Intel
#
#                          OS
# 0                       Mac
# 1                       Mac
# 2     Others/ No OS / Linux
# 3                       Mac
# 4                       Mac
# ...                     ...
# 1298                Windows
# 1299                Windows
# 1300                Windows
# 1301                Windows
# 1302                Windows
#
# [1302 rows x 12 columns]

# %%
import numpy as np
